# %% [markdown]
# # DQN Implementation for CartPole environment

# %% [markdown]
# ## Import required libraries

# %%
import json
import random
import time
from collections import deque

import gym
import keras
import numpy as np
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import matplotlib.animation as animation
# Out:
# 2023-10-28 11:53:41.740725: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Define DQNAgent Class

# %%
class DQNAgent:
    
    def __init__(self, state_size, action_size):

        self.state_size = state_size
        self.action_size = action_size
        
        # Initialize Replay Buffer as python deque
        self.replay_buffer = deque(maxlen=100000)
        
        # Set algorithm hyperparameters
        self.gamma = 0.99
        self.epsilon = 1.
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.98
        self.learning_rate = 0.001
        self.update_rate = 10
        
        # Create both Main and Target Networks
        self.main_network = self.create_nn()
        self.target_network = self.create_nn()
        
        # Initialize Target Network with Main Network's weights
        self.update_target_network()

    def create_nn(self):
        
        model = Sequential()

        model.add(Dense(64, activation='relu', input_dim=self.state_size))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))

        model.compile(loss='mse', optimizer=Adam(learning_rate=self.learning_rate))

        return model
    
    def update_target_network(self):
        # Method to set the Main NN's weights on the Target NN
        self.target_network.set_weights(self.main_network.get_weights())

    def save_experience(self, state, action, reward, next_state, terminal):
        
        # Save the given experience as a (s, a, r, s', terminal) tuple
        self.replay_buffer.append((state, action, reward, next_state, terminal))

    def sample_experience_batch(self, batch_size):
        
        # Sample {batchsize} experiences from the ReplayBuffer
        exp_batch = random.sample(self.replay_buffer, batch_size)

        # Create an array with the {batchsize} elements for s, a, r, s' and terminal information
        state_batch = np.array([batch[0] for batch in exp_batch]).reshape(batch_size, self.state_size)
        action_batch = np.array([batch[1] for batch in exp_batch])
        reward_batch = [batch[2] for batch in exp_batch]
        next_state_batch = np.array([batch[3] for batch in exp_batch]).reshape(batch_size, self.state_size)
        terminal_batch = [batch[4] for batch in exp_batch]

        # Return a tuple, where each item corresponds to each array/batch created above
        return state_batch, action_batch, reward_batch, next_state_batch, terminal_batch

    def pick_epsilon_greedy_action(self, state):

        # Pick random action with probability ε
        if random.uniform(0, 1) < self.epsilon:
            return np.random.randint(self.action_size)

        # Pick action with highest Q-Value (item with highest value for Main NN's output)
        state = state.reshape((1, self.state_size))
        q_values = self.main_network.predict(state, verbose=0)
        return np.argmax(q_values[0])

    def train(self, batch_size):

        # Sample a batch of experiences
        state_batch, action_batch, reward_batch, next_state_batch, terminal_batch = self.sample_experience_batch(batch_size)

        # Get the actions with highest Q-Value for the batch of next states
        next_q = self.target_network.predict(next_state_batch, verbose=0)
        max_next_q = np.amax(next_q, axis=1)
        # Get the Q-values of each state in the batch of states
        q_values = self.main_network.predict(state_batch, verbose=0)

        # Update the Q-Value corresponding to the current action with the Target Value
        for i in range(batch_size):
            q_values[i][action_batch[i]] = reward_batch[i] if terminal_batch[i] else reward_batch[i] + self.gamma * max_next_q[i]

        # Fit the network
        self.main_network.fit(state_batch, q_values, verbose=0)

# %% [markdown]
# ## Implement flow for DQN algorithm

# %% [markdown]
# ### 1. Initialize Gym Environment

# %%
# Initialize CartPole environment
env = gym.make('CartPole-v1')

# Define state and action size
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# %% [markdown]
# ### 2. Define number of episodes, timesteps per episode and batch size

# %%
num_episodes = 150
num_timesteps = 500
batch_size = 64

# %% [markdown]
# ### 3. Initlaize DQNAgent

# %%
dqn_agent = DQNAgent(state_size, action_size)
# Out:
# 2023-10-28 11:53:52.619776: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-10-28 11:53:52.619834: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:168] retrieving CUDA diagnostic information for host: 86034e89439d
# 2023-10-28 11:53:52.619853: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:175] hostname: 86034e89439d
# 2023-10-28 11:53:52.620016: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:199] libcuda reported version is: 530.30.2
# 2023-10-28 11:53:52.620060: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:203] kernel reported version is: 530.30.2
# 2023-10-28 11:53:52.620076: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:309] kernel version seems to match DSO: 530.30.2

# %% [markdown]
# ### 4. Implement and execute flow of DQN algorithm

# %%
rewards, epsilon_values = list(), list() # Lists to keep logs of rewards and apsilon values, for plotting later
time_step = 0 # Initalize timestep counter

for ep in range(num_episodes):
    
    tot_reward = 0
    state, _ = env.reset()
    
    print(f'\nTraining on EPISODE {ep+1} with epsilon {dqn_agent.epsilon}')
    start = time.time()
    
    for t in range(num_timesteps):
        
        time_step += 1
        
        # Update Target Network every {dqn_agent.update_rate} timesteps
        if time_step % dqn_agent.update_rate == 0:
            dqn_agent.update_target_network()
            
        action = dqn_agent.pick_epsilon_greedy_action(state) # Select action with ε-greedy policy
        next_state, reward, terminal, _, _ = env.step(action) # Perform action on environment
        dqn_agent.save_experience(state, action, reward, next_state, terminal) # Save experience in ReplayBuffer

        state = next_state
        tot_reward += reward

        if terminal:
            print('Episode: ', ep+1, ' terminated with Reward ', tot_reward)
            break

        # Train the Main Network when ReplayBuffer has enough experiences to fill a batch
        if len(dqn_agent.replay_buffer) > batch_size:
            dqn_agent.train(batch_size)

    rewards.append(tot_reward)
    epsilon_values.append(dqn_agent.epsilon)
    
    # Everytime an episode is finished, update Epsilon value to a lower value
    if dqn_agent.epsilon > dqn_agent.epsilon_min:
        dqn_agent.epsilon *= dqn_agent.epsilon_decay
        
    # Print information about the Episode performed
    elapsed = time.time() - start
    print(f'Time elapsed during EPISODE {ep+1}: {elapsed} seconds = {round(elapsed/60, 3)} minutes')

    # If the agent got a reward >499 in each of the last 10 episodes, the training is terminated
    if sum(rewards[-10:]) > 4990:
        print('Training stopped because agent has performed a perfect episode in the last 10 episodes')
        break
# Out:
# Training on EPISODE 1 with epsilon 1.0
# Episode:  1  terminated with Reward  17.0
# Time elapsed during EPISODE 1: 0.00600123405456543 seconds = 0.0 minutes
#
# Training on EPISODE 2 with epsilon 0.98
# Episode:  2  terminated with Reward  21.0
# Time elapsed during EPISODE 2: 0.0075838565826416016 seconds = 0.0 minutes
#
# Training on EPISODE 3 with epsilon 0.9603999999999999
# Episode:  3  terminated with Reward  15.0
# Time elapsed during EPISODE 3: 0.007492542266845703 seconds = 0.0 minutes
#
# Training on EPISODE 4 with epsilon 0.9411919999999999
# Episode:  4  terminated with Reward  11.0
# Time elapsed during EPISODE 4: 0.003637552261352539 seconds = 0.0 minutes
#
# Training on EPISODE 5 with epsilon 0.9223681599999999
# Episode:  5  terminated with Reward  13.0
# Time elapsed during EPISODE 5: 3.3063156604766846 seconds = 0.055 minutes
#
# Training on EPISODE 6 with epsilon 0.9039207967999998
# Episode:  6  terminated with Reward  25.0
# Time elapsed during EPISODE 6: 3.206516981124878 seconds = 0.053 minutes
#
# Training on EPISODE 7 with epsilon 0.8858423808639998
# Episode:  7  terminated with Reward  29.0
# Time elapsed during EPISODE 7: 3.76285457611084 seconds = 0.063 minutes
#
# Training on EPISODE 8 with epsilon 0.8681255332467198
# Episode:  8  terminated with Reward  9.0
# Time elapsed during EPISODE 8: 1.1407687664031982 seconds = 0.019 minutes
#
# Training on EPISODE 9 with epsilon 0.8507630225817854
# Episode:  9  terminated with Reward  13.0
# Time elapsed during EPISODE 9: 1.6415820121765137 seconds = 0.027 minutes
#
# Training on EPISODE 10 with epsilon 0.8337477621301497
# Episode:  10  terminated with Reward  19.0
# Time elapsed during EPISODE 10: 2.5196495056152344 seconds = 0.042 minutes
#
# Training on EPISODE 11 with epsilon 0.8170728068875467
# Episode:  11  terminated with Reward  18.0
# Time elapsed during EPISODE 11: 2.1905837059020996 seconds = 0.037 minutes
#
# Training on EPISODE 12 with epsilon 0.8007313507497957
# Episode:  12  terminated with Reward  16.0
# Time elapsed during EPISODE 12: 2.0606658458709717 seconds = 0.034 minutes
#
# Training on EPISODE 13 with epsilon 0.7847167237347998
# Episode:  13  terminated with Reward  12.0
# Time elapsed during EPISODE 13: 1.4254827499389648 seconds = 0.024 minutes
#
# Training on EPISODE 14 with epsilon 0.7690223892601038
# Episode:  14  terminated with Reward  11.0
# Time elapsed during EPISODE 14: 1.4122958183288574 seconds = 0.024 minutes
#
# Training on EPISODE 15 with epsilon 0.7536419414749017
# Episode:  15  terminated with Reward  29.0
# Time elapsed during EPISODE 15: 3.701934576034546 seconds = 0.062 minutes
#
# Training on EPISODE 16 with epsilon 0.7385691026454037
# Episode:  16  terminated with Reward  22.0
# Time elapsed during EPISODE 16: 2.7647368907928467 seconds = 0.046 minutes
#
# Training on EPISODE 17 with epsilon 0.7237977205924956
# Episode:  17  terminated with Reward  23.0
# Time elapsed during EPISODE 17: 3.273531913757324 seconds = 0.055 minutes
#
# Training on EPISODE 18 with epsilon 0.7093217661806457
# Episode:  18  terminated with Reward  56.0
# Time elapsed during EPISODE 18: 7.600503444671631 seconds = 0.127 minutes
#
# Training on EPISODE 19 with epsilon 0.6951353308570327
# Episode:  19  terminated with Reward  13.0
# Time elapsed during EPISODE 19: 1.6892163753509521 seconds = 0.028 minutes
#
# Training on EPISODE 20 with epsilon 0.6812326242398921
# Episode:  20  terminated with Reward  28.0
# Time elapsed during EPISODE 20: 4.260563611984253 seconds = 0.071 minutes
#
# Training on EPISODE 21 with epsilon 0.6676079717550942
# Episode:  21  terminated with Reward  29.0
# Time elapsed during EPISODE 21: 3.7306528091430664 seconds = 0.062 minutes
#
# Training on EPISODE 22 with epsilon 0.6542558123199923
# Episode:  22  terminated with Reward  15.0
# Time elapsed during EPISODE 22: 1.7507379055023193 seconds = 0.029 minutes
#
# Training on EPISODE 23 with epsilon 0.6411706960735924
# Episode:  23  terminated with Reward  34.0
# Time elapsed during EPISODE 23: 4.607564210891724 seconds = 0.077 minutes
#
# Training on EPISODE 24 with epsilon 0.6283472821521205
# Episode:  24  terminated with Reward  19.0
# Time elapsed during EPISODE 24: 2.5760982036590576 seconds = 0.043 minutes
#
# Training on EPISODE 25 with epsilon 0.6157803365090782
# Episode:  25  terminated with Reward  34.0
# Time elapsed during EPISODE 25: 4.751132249832153 seconds = 0.079 minutes
#
# Training on EPISODE 26 with epsilon 0.6034647297788965
# Episode:  26  terminated with Reward  27.0
# Time elapsed during EPISODE 26: 4.034148454666138 seconds = 0.067 minutes
#
# Training on EPISODE 27 with epsilon 0.5913954351833186
# Episode:  27  terminated with Reward  20.0
# Time elapsed during EPISODE 27: 2.790597677230835 seconds = 0.047 minutes
#
# Training on EPISODE 28 with epsilon 0.5795675264796523
# Episode:  28  terminated with Reward  141.0
# Time elapsed during EPISODE 28: 22.392446756362915 seconds = 0.373 minutes
#
# Training on EPISODE 29 with epsilon 0.5679761759500592
# Episode:  29  terminated with Reward  32.0
# Time elapsed during EPISODE 29: 4.2689049243927 seconds = 0.071 minutes
#
# Training on EPISODE 30 with epsilon 0.5566166524310581
# Episode:  30  terminated with Reward  53.0
# Time elapsed during EPISODE 30: 7.2472639083862305 seconds = 0.121 minutes
#
# Training on EPISODE 31 with epsilon 0.5454843193824369
# Episode:  31  terminated with Reward  49.0
# Time elapsed during EPISODE 31: 6.905480146408081 seconds = 0.115 minutes
#
# Training on EPISODE 32 with epsilon 0.5345746329947881
# Episode:  32  terminated with Reward  53.0
# Time elapsed during EPISODE 32: 8.16750693321228 seconds = 0.136 minutes
#
# Training on EPISODE 33 with epsilon 0.5238831403348924
# Episode:  33  terminated with Reward  43.0
# Time elapsed during EPISODE 33: 6.012090444564819 seconds = 0.1 minutes
#
# Training on EPISODE 34 with epsilon 0.5134054775281945
# Episode:  34  terminated with Reward  109.0
# Time elapsed during EPISODE 34: 16.86674213409424 seconds = 0.281 minutes
#
# Training on EPISODE 35 with epsilon 0.5031373679776306
# Episode:  35  terminated with Reward  49.0
# Time elapsed during EPISODE 35: 6.786942720413208 seconds = 0.113 minutes
#
# Training on EPISODE 36 with epsilon 0.493074620618078
# Episode:  36  terminated with Reward  94.0
# Time elapsed during EPISODE 36: 13.566241264343262 seconds = 0.226 minutes
#
# Training on EPISODE 37 with epsilon 0.48321312820571644
# Episode:  37  terminated with Reward  17.0
# Time elapsed during EPISODE 37: 2.086942434310913 seconds = 0.035 minutes
#
# Training on EPISODE 38 with epsilon 0.4735488656416021
# Episode:  38  terminated with Reward  37.0
# Time elapsed during EPISODE 38: 5.149917125701904 seconds = 0.086 minutes
#
# Training on EPISODE 39 with epsilon 0.46407788832877006
# Episode:  39  terminated with Reward  117.0
# Time elapsed during EPISODE 39: 17.038512229919434 seconds = 0.284 minutes
#
# Training on EPISODE 40 with epsilon 0.45479633056219465
# Episode:  40  terminated with Reward  88.0
# Time elapsed during EPISODE 40: 12.414560079574585 seconds = 0.207 minutes
#
# Training on EPISODE 41 with epsilon 0.44570040395095073
# Episode:  41  terminated with Reward  46.0
# Time elapsed during EPISODE 41: 6.264415979385376 seconds = 0.104 minutes
#
# Training on EPISODE 42 with epsilon 0.4367863958719317
# Episode:  42  terminated with Reward  107.0
# Time elapsed during EPISODE 42: 16.02396535873413 seconds = 0.267 minutes
#
# Training on EPISODE 43 with epsilon 0.42805066795449304
# Episode:  43  terminated with Reward  103.0
# Time elapsed during EPISODE 43: 14.271750450134277 seconds = 0.238 minutes
#
# Training on EPISODE 44 with epsilon 0.41948965459540316
# Episode:  44  terminated with Reward  156.0
# Time elapsed during EPISODE 44: 23.10258722305298 seconds = 0.385 minutes
#
# Training on EPISODE 45 with epsilon 0.4110998615034951
# Episode:  45  terminated with Reward  67.0
# Time elapsed during EPISODE 45: 9.380120277404785 seconds = 0.156 minutes
#
# Training on EPISODE 46 with epsilon 0.4028778642734252
# Episode:  46  terminated with Reward  125.0
# Time elapsed during EPISODE 46: 18.60097575187683 seconds = 0.31 minutes
#
# Training on EPISODE 47 with epsilon 0.39482030698795667
# Episode:  47  terminated with Reward  170.0
# Time elapsed during EPISODE 47: 24.384317874908447 seconds = 0.406 minutes
#
# Training on EPISODE 48 with epsilon 0.38692390084819756
# Episode:  48  terminated with Reward  127.0
# Time elapsed during EPISODE 48: 18.59065341949463 seconds = 0.31 minutes
#
# Training on EPISODE 49 with epsilon 0.3791854228312336
# Episode:  49  terminated with Reward  197.0
# Time elapsed during EPISODE 49: 29.18535327911377 seconds = 0.486 minutes
#
# Training on EPISODE 50 with epsilon 0.37160171437460887
# Episode:  50  terminated with Reward  193.0
# Time elapsed during EPISODE 50: 28.001149654388428 seconds = 0.467 minutes
#
# Training on EPISODE 51 with epsilon 0.3641696800871167
# Episode:  51  terminated with Reward  77.0
# Time elapsed during EPISODE 51: 10.942044496536255 seconds = 0.182 minutes
#
# Training on EPISODE 52 with epsilon 0.35688628648537435
# Episode:  52  terminated with Reward  259.0
# Time elapsed during EPISODE 52: 38.25794529914856 seconds = 0.638 minutes
#
# Training on EPISODE 53 with epsilon 0.34974856075566685
# Episode:  53  terminated with Reward  136.0
# Time elapsed during EPISODE 53: 20.78313946723938 seconds = 0.346 minutes
#
# Training on EPISODE 54 with epsilon 0.3427535895405535
# Episode:  54  terminated with Reward  266.0
# Time elapsed during EPISODE 54: 39.95275855064392 seconds = 0.666 minutes
#
# Training on EPISODE 55 with epsilon 0.33589851774974244
# Episode:  55  terminated with Reward  226.0
# Time elapsed during EPISODE 55: 34.48573541641235 seconds = 0.575 minutes
#
# Training on EPISODE 56 with epsilon 0.3291805473947476
# Episode:  56  terminated with Reward  151.0
# Time elapsed during EPISODE 56: 22.893078565597534 seconds = 0.382 minutes
#
# Training on EPISODE 57 with epsilon 0.32259693644685267
# Episode:  57  terminated with Reward  191.0
# Time elapsed during EPISODE 57: 28.53224229812622 seconds = 0.476 minutes
#
# Training on EPISODE 58 with epsilon 0.3161449977179156
# Episode:  58  terminated with Reward  281.0
# Time elapsed during EPISODE 58: 42.324246644973755 seconds = 0.705 minutes
#
# Training on EPISODE 59 with epsilon 0.3098220977635573
# Episode:  59  terminated with Reward  60.0
# Time elapsed during EPISODE 59: 8.86289095878601 seconds = 0.148 minutes
#
# Training on EPISODE 60 with epsilon 0.30362565580828615
# Episode:  60  terminated with Reward  121.0
# Time elapsed during EPISODE 60: 17.69380474090576 seconds = 0.295 minutes
#
# Training on EPISODE 61 with epsilon 0.2975531426921204
# Episode:  61  terminated with Reward  413.0
# Time elapsed during EPISODE 61: 60.725332736968994 seconds = 1.012 minutes
#
# Training on EPISODE 62 with epsilon 0.291602079838278
# Episode:  62  terminated with Reward  75.0
# Time elapsed during EPISODE 62: 11.564887285232544 seconds = 0.193 minutes
#
# Training on EPISODE 63 with epsilon 0.2857700382415124
# Episode:  63  terminated with Reward  265.0
# Time elapsed during EPISODE 63: 39.84569025039673 seconds = 0.664 minutes
#
# Training on EPISODE 64 with epsilon 0.2800546374766822
# Time elapsed during EPISODE 64: 75.5597071647644 seconds = 1.259 minutes
#
# Training on EPISODE 65 with epsilon 0.27445354472714856
# Episode:  65  terminated with Reward  107.0
# Time elapsed during EPISODE 65: 16.016999006271362 seconds = 0.267 minutes
#
# Training on EPISODE 66 with epsilon 0.2689644738326056
# Time elapsed during EPISODE 66: 77.45498251914978 seconds = 1.291 minutes
#
# Training on EPISODE 67 with epsilon 0.26358518435595346
# Episode:  67  terminated with Reward  447.0
# Time elapsed during EPISODE 67: 70.22465801239014 seconds = 1.17 minutes
#
# Training on EPISODE 68 with epsilon 0.25831348066883436
# Time elapsed during EPISODE 68: 78.79288172721863 seconds = 1.313 minutes
#
# Training on EPISODE 69 with epsilon 0.2531472110554577
# Time elapsed during EPISODE 69: 77.27371144294739 seconds = 1.288 minutes
#
# Training on EPISODE 70 with epsilon 0.24808426683434853
# Time elapsed during EPISODE 70: 78.43489480018616 seconds = 1.307 minutes
#
# Training on EPISODE 71 with epsilon 0.24312258149766156
# Time elapsed during EPISODE 71: 76.87818264961243 seconds = 1.281 minutes
#
# Training on EPISODE 72 with epsilon 0.2382601298677083
# Time elapsed during EPISODE 72: 77.33139133453369 seconds = 1.289 minutes
#
# Training on EPISODE 73 with epsilon 0.23349492727035415
# Time elapsed during EPISODE 73: 78.03505277633667 seconds = 1.301 minutes
#
# Training on EPISODE 74 with epsilon 0.22882502872494706
# Time elapsed during EPISODE 74: 77.05870962142944 seconds = 1.284 minutes
#
# Training on EPISODE 75 with epsilon 0.22424852815044813
# Time elapsed during EPISODE 75: 78.29378843307495 seconds = 1.305 minutes
#
# Training on EPISODE 76 with epsilon 0.21976355758743915
# Time elapsed during EPISODE 76: 78.50489115715027 seconds = 1.308 minutes
#
# Training on EPISODE 77 with epsilon 0.21536828643569036
# Time elapsed during EPISODE 77: 76.84873580932617 seconds = 1.281 minutes
# Training stopped because agent has performed a perfect episode in the last 10 episodes

# %% [markdown]
# ### 5. Test the trained by executing an episode

# %% [markdown]
# #### The test executes a complete episode without visualization, because of running in a JupyterNotebook. A test episode with visualization can be executed with the python script *dqn.py* available in the ArtificalIntelligence repository, in the DQN folder

# %%
def select_trained_agent_action(state, trained_model):
    q_values = trained_model.predict(state, verbose=0)
    return np.argmax(q_values[0])

# %%
env = gym.make('CartPole-v1', render_mode='rgb_array')
state, _ = env.reset()
state_size = env.observation_space.shape[0]
total_reward = 0
max_timesteps = 500

# Execute episode
for t in range(max_timesteps):
    print(f'Running frame {t+1}...', end='\r')
    
    state = state.reshape((1, state_size))
    action = select_trained_agent_action(state, dqn_agent.main_network)
    next_state, reward, terminal, _, _ = env.step(action)
    
    total_reward += reward
    state = next_state
    
env.close()
    
print(f'Test episode terminated with reward {total_reward} (Max Reward=500)')
# Out:
# Test episode terminated with reward 500.0 (Max Reward=500)

# %% [markdown]
# ### 6. Plot mean rewards of the agent

# %%
import matplotlib.pyplot as plt

# %%
def plot_rewards(mean_range=1):
    
    # The parameter mean_range must allow equal separation of rewards
    if len(rewards) % mean_range != 0:
        raise ValueError
        
    # Calculate mean rewards
    mean_rewards = list()
    for i in range(round(len(rewards)/mean_range)):
        reward_on_range = rewards[i*mean_range:i*mean_range+mean_range]
        reward_on_range_mean = round(sum(reward_on_range)/len(reward_on_range))
        mean_rewards.append(reward_on_range_mean)
        
    plt.plot(range(len(mean_rewards)), mean_rewards)
    plt.show()

# %%
plot_rewards()

# %% [markdown]
# ### 7. Plot values of epsilon during the training

# %%
def plot_epsilon_values():
    
    plt.plot(range(len(epsilon_values)), epsilon_values)
    plt.show()

# %%
plot_epsilon_values()
