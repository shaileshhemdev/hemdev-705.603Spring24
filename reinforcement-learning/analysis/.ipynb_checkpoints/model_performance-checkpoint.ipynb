# %%
# Set up the notebook to import modules from relative paths
import os, sys

#'/home/user/example/parent/child'
current_path = os.path.abspath('.')

#'/home/user/example/parent'
parent_path = os.path.dirname(current_path)

sys.path.append(parent_path)

# %%
from data_pipeline import ETL_Pipeline 

dp = ETL_Pipeline('/workspace/shared-data/email-campaign/')
transformed_df = dp.process('sent_emails.csv','responded.csv','userbase.csv')
transformed_df.head()
# Out:
#    SubjectLine_ID  Gender  Type  Email_Domain  Age_Group  Tenure_Group  \
# 0               2       1     0             2          3             2
# 1               2       1     1             3          2             4
# 2               3       1     1             2          2             2
# 3               1       1     1             2          2             3
# 4               3       1     1             4          2             1
#
#    Response_Received  Sent_Day
# 0                  1         3
# 1                  0         2
# 2                  0         2
# 3                  0         2
# 4                  1         2

# %%
import pandas as pd
import numpy as np
import sklearn

from IPython.display import display, HTML

# Display Properties
from IPython.display import display, HTML
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df = pd.read_csv('/workspace/shared-data/email-campaign/email_campaign_data.csv')
df.head()
# Out:
#    SubjectLine_ID  Gender  Type  Email_Domain  Age_Group  Tenure_Group  Response_Received  Sent_Day
# 0         2           1      0         2           3            2               1              3
# 1         2           1      1         3           2            4               0              2
# 2         3           1      1         2           2            2               0              2
# 3         1           1      1         2           2            3               0              2
# 4         3           1      1         4           2            1               1              2

# %%
from dataset import Email_Dataset

# Create a email campaign dataset with 5 folds 
ecd = Email_Dataset(df,'Response_Received')

# Get training dataset for a fold
training_df = ecd.get_training_dataset(2)
training_df.head()
# Out:
#    SubjectLine_ID  Gender  Type  Email_Domain  Age_Group  Tenure_Group  Sent_Day  Response_Received
# 0         2           1      0         2           3            2           3             1
# 1         2           1      1         3           2            4           2             0
# 2         3           1      1         2           2            2           2             0
# 3         1           1      1         2           2            3           2             0
# 4         3           1      1         4           2            1           2             1

# %%
# Get testing dataset for a fold
testing_df = ecd.get_testing_dataset(2)
testing_df.head()
# Out:
#    SubjectLine_ID  Gender  Type  Email_Domain  Age_Group  Tenure_Group  Sent_Day  Response_Received
# 0         2           0      1         4           2            2           3             0
# 1         2           1      0         4           3            3           5             0
# 2         1           1      1         2           2            5           6             0
# 3         3           1      1         5           0            2           4             0
# 4         1           0      1         2           2            3           5             0

# %%
print(f"We have {len(training_df)} training responses and {len(testing_df)} testing responses")
# Out:
# We have 1981083 training responses and 495271 testing responses

# %%
from model import Email_Campaign_Model
from metrics import Metrics

metrics = Metrics()

# Train the Model using entire dataset and with defaults of conversion threshold of 30% and sent emails as 10
model = Email_Campaign_Model(df)
# Out:
# Here we will build the state table

# %%
qtable_df = model.train(iterations=10000, starting_state = (1,0,0,0,0,0,0), epsilon = 0.1, alpha = 0.1,gamma = 0.6)
qtable_df.head()

# %%
qtable_df.to_csv('q_table.csv')

# %%
# Load the model again but now with the Q Table generated from training and we now don't need to consider the email sent 
# threshold as we have trained the model to get Q Table Values using that
saved_model = Email_Campaign_Model(df, (1,0,0,0,0,0,0), 1, 0.25, 'q_table.csv', model.get_states())

# Run metrics using this Q Table across different splits
folds = []
avg_conv = []
median_conv = []
min_conv = []
max_conv = [] 

# Run through all the folds
for i in range(5):
    # Get training for the fold and get metrics
    train = ecd.get_training_dataset(i)
    avg, median, min_conversion, max_conversion = saved_model.test(train,10)
    folds += ['Training Fold ' + str(i)]
    avg_conv += [avg]
    median_conv += [median]
    min_conv += [min_conversion]
    max_conv += [max_conversion] 
    print('Completed fold ' + str(i))

metrics.generate_report(folds,avg_conv,median_conv,min_conv,max_conv,'../results/training-results.txt')
# Out:
# We have 83 responded emails out of 205 sent for subject 1 with conversion rate 0.40487804878048783
# We have 24 responded emails out of 55 sent for subject 1 with conversion rate 0.43636363636363634
# We have 217 responded emails out of 777 sent for subject 3 with conversion rate 0.27927927927927926
# We have 38 responded emails out of 97 sent for subject 1 with conversion rate 0.3917525773195876
# We have 65 responded emails out of 139 sent for subject 1 with conversion rate 0.4676258992805755
# We have 3 responded emails out of 7 sent for subject 2 with conversion rate 0.42857142857142855
# We have 125 responded emails out of 300 sent for subject 1 with conversion rate 0.4166666666666667
# We have 264 responded emails out of 820 sent for subject 3 with conversion rate 0.32195121951219513
# We have 131 responded emails out of 491 sent for subject 3 with conversion rate 0.2668024439918534
# We have 140 responded emails out of 493 sent for subject 1 with conversion rate 0.2839756592292089
# Completed fold 0
# We have 146 responded emails out of 578 sent for subject 3 with conversion rate 0.25259515570934254
# We have 319 responded emails out of 956 sent for subject 1 with conversion rate 0.33368200836820083
# We have 71 responded emails out of 252 sent for subject 3 with conversion rate 0.28174603174603174
# We have 414 responded emails out of 1036 sent for subject 2 with conversion rate 0.3996138996138996
# We have 298 responded emails out of 872 sent for subject 1 with conversion rate 0.34174311926605505
# We have 106 responded emails out of 336 sent for subject 1 with conversion rate 0.31547619047619047
# We have 190 responded emails out of 609 sent for subject 2 with conversion rate 0.31198686371100165
# We have 1271 responded emails out of 3674 sent for subject 2 with conversion rate 0.34594447468698963
# We have 86 responded emails out of 258 sent for subject 2 with conversion rate 0.3333333333333333
# We have 31 responded emails out of 113 sent for subject 3 with conversion rate 0.2743362831858407
# Completed fold 1
# We have 43 responded emails out of 122 sent for subject 2 with conversion rate 0.3524590163934426
# We have 128 responded emails out of 401 sent for subject 3 with conversion rate 0.3192019950124688
# We have 275 responded emails out of 817 sent for subject 3 with conversion rate 0.33659730722154224
# We have 369 responded emails out of 1236 sent for subject 3 with conversion rate 0.29854368932038833
# We have 317 responded emails out of 1002 sent for subject 3 with conversion rate 0.31636726546906185
# We have 172 responded emails out of 450 sent for subject 2 with conversion rate 0.38222222222222224
# We have 578 responded emails out of 1696 sent for subject 1 with conversion rate 0.3408018867924528
# We have 25 responded emails out of 117 sent for subject 3 with conversion rate 0.21367521367521367
# We have 69 responded emails out of 262 sent for subject 3 with conversion rate 0.2633587786259542
# We have 119 responded emails out of 361 sent for subject 3 with conversion rate 0.3296398891966759
# We have 18 responded emails out of 45 sent for subject 3 with conversion rate 0.4
# Completed fold 2
# We have 423 responded emails out of 1512 sent for subject 3 with conversion rate 0.27976190476190477
# We have 43 responded emails out of 131 sent for subject 2 with conversion rate 0.3282442748091603
# We have 325 responded emails out of 901 sent for subject 1 with conversion rate 0.3607103218645949
# We have 1589 responded emails out of 4437 sent for subject 1 with conversion rate 0.35812485913905795
# We have 294 responded emails out of 950 sent for subject 3 with conversion rate 0.3094736842105263
# We have 109 responded emails out of 231 sent for subject 1 with conversion rate 0.47186147186147187
# We have 284 responded emails out of 892 sent for subject 3 with conversion rate 0.3183856502242152
# We have 149 responded emails out of 427 sent for subject 2 with conversion rate 0.34894613583138173
# We have 289 responded emails out of 797 sent for subject 2 with conversion rate 0.36260978670012545
# We have 46 responded emails out of 173 sent for subject 3 with conversion rate 0.2658959537572254
# Completed fold 3
# We have 489 responded emails out of 1443 sent for subject 1 with conversion rate 0.3388773388773389
# We have 188 responded emails out of 557 sent for subject 3 with conversion rate 0.3375224416517056
# We have 1110 responded emails out of 3655 sent for subject 3 with conversion rate 0.3036935704514364
# We have 1026 responded emails out of 3294 sent for subject 3 with conversion rate 0.3114754098360656
# We have 1365 responded emails out of 4311 sent for subject 3 with conversion rate 0.3166318719554628
# We have 194 responded emails out of 536 sent for subject 3 with conversion rate 0.3619402985074627
# We have 125 responded emails out of 367 sent for subject 1 with conversion rate 0.3405994550408719
# We have 197 responded emails out of 458 sent for subject 2 with conversion rate 0.43013100436681223
# We have 352 responded emails out of 1065 sent for subject 3 with conversion rate 0.3305164319248826
# We have 299 responded emails out of 806 sent for subject 2 with conversion rate 0.3709677419354839
# Completed fold 4

# %%
# Run metrics using this Q Table across different splits
folds = []
avg_conv = []
median_conv = []
min_conv = []
max_conv = [] 

# Run through all the folds
for i in range(5):
    # Get training for the fold and get metrics
    test = ecd.get_testing_dataset(i)
    avg, median, min_conversion, max_conversion = saved_model.test(test,10)
    folds += ['Training Fold ' + str(i)]
    avg_conv += [avg]
    median_conv += [median]
    min_conv += [min_conversion]
    max_conv += [max_conversion] 

metrics.generate_report(folds,avg_conv,median_conv,min_conv,max_conv,'../results/testing-results.txt')
# Out:
# We have 355 responded emails out of 1081 sent for subject 1 with conversion rate 0.3283996299722479
# We have 28 responded emails out of 84 sent for subject 3 with conversion rate 0.3333333333333333
# We have 41 responded emails out of 180 sent for subject 2 with conversion rate 0.22777777777777777
# We have 50 responded emails out of 202 sent for subject 2 with conversion rate 0.24752475247524752
# We have 53 responded emails out of 217 sent for subject 2 with conversion rate 0.24423963133640553
# We have 57 responded emails out of 234 sent for subject 2 with conversion rate 0.24358974358974358
# We have 65 responded emails out of 253 sent for subject 2 with conversion rate 0.25691699604743085
# We have 254 responded emails out of 686 sent for subject 2 with conversion rate 0.37026239067055394
# We have 24 responded emails out of 54 sent for subject 2 with conversion rate 0.4444444444444444
# We have 59 responded emails out of 150 sent for subject 2 with conversion rate 0.3933333333333333
# We have 501 responded emails out of 1761 sent for subject 3 with conversion rate 0.28449744463373083
# We have 37 responded emails out of 127 sent for subject 1 with conversion rate 0.29133858267716534
# We have 24 responded emails out of 63 sent for subject 3 with conversion rate 0.38095238095238093
# We have 1303 responded emails out of 3700 sent for subject 2 with conversion rate 0.3521621621621622
# We have 1396 responded emails out of 4021 sent for subject 1 with conversion rate 0.347177319074857
